# %%
# %store -r merged_df
# %store -r merged_df_clean
df = merged_df_clean.copy()
df.isnull().sum()
# Out:
# state_code                                 0
# period                                     0
# value                                      0
# Crude Oil Production                       0
# Dry Natural Gas Production                 0
# Coal Production                            0
# Total Energy Production (qBtu)             0
# Liquid Fuels Consumption                   0
# Natural Gas Consumption                    0
# Coal Consumption                           0
# Electricity Consumption                    0
# Renewables Consumption                     0
# Total Energy Consumption (qBtu)            0
# Crude Oil ($/barrel)                       0
# Natural Gas ($/mBtu)                       0
# Coal ($/mBtu)                              0
# Real Gross Domestic Product (Trillions)    0
# RGDP Percent change YOY (%)                0
# GDP Implicit Price Deflator                0
# GDP IPD Percent change YOY (%)             0
# Real Disposable Personal Income            0
# RDPI Percent change YOY (%)                0
# Manufacturing Production Index             0
# MPI Percent change YOY (%)                 0
# state_name_California                      0
# state_name_Colorado                        0
# state_name_Florida                         0
# state_name_New York                        0
# state_name_Texas                           0
# dtype: int64

# %%
import pandas as pd

# Extract year and month into new columns to put into nerual network
time_df = df
time_df['year'] = df['period'].dt.year
time_df['month'] = df['period'].dt.month

time_df.columns
# Out:
# Index(['state_code', 'period', 'value', 'Crude Oil Production',
#        'Dry Natural Gas Production', 'Coal Production',
#        'Total Energy Production (qBtu)', 'Liquid Fuels Consumption',
#        'Natural Gas Consumption', 'Coal Consumption',
#        'Electricity Consumption', 'Renewables Consumption',
#        'Total Energy Consumption (qBtu)', 'Crude Oil ($/barrel)',
#        'Natural Gas ($/mBtu) ', 'Coal ($/mBtu)',
#        'Real Gross Domestic Product (Trillions)',
#        'RGDP Percent change YOY (%)', 'GDP Implicit Price Deflator',
#        'GDP IPD Percent change YOY (%)', 'Real Disposable Personal Income',
#        'RDPI Percent change YOY (%)', 'Manufacturing Production Index',
#        'MPI Percent change YOY (%)', 'state_name_California',
#        'state_name_Colorado', 'state_name_Florida', 'state_name_New York',
#        'state_name_Texas', 'year', 'month'],
#       dtype='object')

# %%
#getting X and Y data
y = time_df.value

features = ['Crude Oil Production',
            'Liquid Fuels Consumption',
            'Electricity Consumption',
            'Crude Oil ($/barrel)',
            'Real Gross Domestic Product (Trillions)',
            'RGDP Percent change YOY (%)',
            'Real Disposable Personal Income',
            'RDPI Percent change YOY (%)',
            'Manufacturing Production Index',
            'MPI Percent change YOY (%)',
            'GDP Implicit Price Deflator',
            'GDP IPD Percent change YOY (%)',
            'state_name_California',
            'state_name_Colorado', 
            'state_name_Florida', 
            'state_name_New York',
            'state_name_Texas',
            'year',
            'month']
            
X = time_df[features]

X.head()
# Out:
#       Crude Oil Production  Liquid Fuels Consumption  Electricity Consumption  \
# 0                      5.4                     18.65                    11.06
# 6957                   5.4                     18.65                    11.06
# 6958                   5.4                     18.65                    11.06
# 6959                   5.4                     18.65                    11.06
# 6960                   5.4                     18.65                    11.06
#
#       Crude Oil ($/barrel)  Real Gross Domestic Product (Trillions)  \
# 0                    78.33                                   16.583
# 6957                 78.33                                   16.583
# 6958                 78.33                                   16.583
# 6959                 78.33                                   16.583
# 6960                 78.33                                   16.583
#
#       RGDP Percent change YOY (%)  Real Disposable Personal Income  \
# 0                             1.7                            12286
# 6957                          1.7                            12286
# 6958                          1.7                            12286
# 6959                          1.7                            12286
# 6960                          1.7                            12286
#
#       RDPI Percent change YOY (%)  Manufacturing Production Index  \
# 0                            -0.6                            89.6
# 6957                         -0.6                            89.6
# 6958                         -0.6                            89.6
# 6959                         -0.6                            89.6
# 6960                         -0.6                            89.6
#
#       MPI Percent change YOY (%)  GDP Implicit Price Deflator  \
# 0                            2.4                         89.0
# 6957                         2.4                         89.0
# 6958                         2.4                         89.0
# 6959                         2.4                         89.0
# 6960                         2.4                         89.0
#
#       GDP IPD Percent change YOY (%)  state_name_California  \
# 0                                0.5                   True
# 6957                             0.5                  False
# 6958                             0.5                  False
# 6959                             0.5                  False
# 6960                             0.5                  False
#
#       state_name_Colorado  state_name_Florida  state_name_New York  \
# 0                   False               False                False
# 6957                False               False                False
# 6958                False               False                False
# 6959                False               False                False
# 6960                False               False                False
#
#       state_name_Texas  year  month
# 0                False  2010      1
# 6957              True  2010      1
# 6958              True  2010      1
# 6959              True  2010      1
# 6960              True  2010      1

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 0)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6861, 19)
# (2288, 19)
# (6861,)
# (2288,)

# %%
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping

#model details
model = keras.Sequential([
    layers.Dense(256, activation='relu', input_shape=[19]),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(1),
])

#lower learning rate
optimizer = keras.optimizers.Adam(learning_rate=0.0001)

#compile model
model.compile(optimizer=optimizer, loss='mae')

#early stopping
early_stopping = EarlyStopping(
    patience=10,
    min_delta=0.001,
    restore_best_weights=True,
)

#training
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    batch_size=128,
    epochs=100,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/100
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 3.3088 - val_loss: 2.4257
# Epoch 2/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2173 - val_loss: 3.5958
# Epoch 3/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.1448 - val_loss: 3.9419
# Epoch 4/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.0496 - val_loss: 3.9341
# Epoch 5/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.9455 - val_loss: 3.6525
# Epoch 6/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8438 - val_loss: 3.3947
# Epoch 7/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7510 - val_loss: 3.2108
# Epoch 8/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6357 - val_loss: 2.9653
# Epoch 9/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5159 - val_loss: 2.8320
# Epoch 10/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3895 - val_loss: 2.4913
# Epoch 11/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2953 - val_loss: 2.2119
# Epoch 12/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1472 - val_loss: 2.0579
# Epoch 13/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0376 - val_loss: 1.7329
# Epoch 14/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9144 - val_loss: 1.4234
# Epoch 15/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8289 - val_loss: 1.4378
# Epoch 16/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7492 - val_loss: 1.2203
# Epoch 17/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6337 - val_loss: 1.1497
# Epoch 18/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5842 - val_loss: 1.0724
# Epoch 19/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5272 - val_loss: 1.0600
# Epoch 20/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4581 - val_loss: 0.9402
# Epoch 21/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4099 - val_loss: 0.9918
# Epoch 22/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3864 - val_loss: 1.0619
# Epoch 23/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3363 - val_loss: 0.9965
# Epoch 24/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3006 - val_loss: 1.1342
# Epoch 25/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2846 - val_loss: 1.0801
# Epoch 26/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2567 - val_loss: 1.0047
# Epoch 27/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2233 - val_loss: 0.9554
# Epoch 28/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2142 - val_loss: 0.8833
# Epoch 29/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2170 - val_loss: 0.8642
# Epoch 30/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1773 - val_loss: 0.8314
# Epoch 31/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1471 - val_loss: 0.8075
# Epoch 32/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1802 - val_loss: 0.7557
# Epoch 33/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1302 - val_loss: 0.7463
# Epoch 34/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1154 - val_loss: 0.7152
# Epoch 35/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1040 - val_loss: 0.7500
# Epoch 36/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1024 - val_loss: 0.7463
# Epoch 37/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0767 - val_loss: 0.7427
# Epoch 38/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0812 - val_loss: 0.7548
# Epoch 39/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0644 - val_loss: 0.7856
# Epoch 40/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0406 - val_loss: 0.8178
# Epoch 41/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0440 - val_loss: 0.7987
# Epoch 42/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0378 - val_loss: 0.7641
# Epoch 43/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0109 - val_loss: 0.7742
# Epoch 44/100
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0020 - val_loss: 0.7353

# %%
history_df = pd.DataFrame(history.history)
#starting plot at epoch 0
history_df.loc[0:, ['loss']].plot()
# Out:
# <Axes: >
